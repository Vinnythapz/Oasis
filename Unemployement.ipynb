# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinnythapz/Oasis/blob/main/Unemployement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt
import numpy as np
df = pd. read_csv('https://raw.githubusercontent.com/Vinnythapz/Oasis/main/Unemployment%20in%20India.csv')
df
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
print(unemployment_in_india.shape)
Print(unemployment_in_india.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-489126aba95c> in <cell line: 1>()
# ----> 1 print(unemployment_in_india.shape)
#       2 Print(unemployment_in_india.columns)
#
# NameError: name 'unemployment_in_india' is not defined
