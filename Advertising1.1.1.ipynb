# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinnythapz/Oasis/blob/main/Advertising1.1.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt
import numpy as np
df = pd.read_csv('https://raw.githubusercontent.com/Vinnythapz/Oasis/main/Advertising.csv')
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
print('Advertising.shape')
# Out:
# Advertising.shape

# %%
print('Advertising.columns')
# Out:
# Advertising.columns

# %%
df["Sales"].value_counts()
# Out:
# Sales
# 9.7     5
# 11.7    4
# 12.9    4
# 15.9    4
# 20.7    3
#        ..
# 17.0    1
# 18.3    1
# 22.3    1
# 14.0    1
# 25.5    1
# Name: count, Length: 121, dtype: int64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('https://raw.githubusercontent.com/Vinnythapz/Oasis/main/Advertising.csv')

print('Advertising.shape')
print('Advertising.columns')

df["Sales"].value_counts()

plt.close('all')
sns.set_style("whitegrid")
sns.pairplot(df, hue="Sales", size=3, diag_kind="kde")
plt.show()
# Out:
# Advertising.shape
# Advertising.columns
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
