# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinnythapz/Oasis/blob/main/Advertising%20dataset%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px

df = pd.read_csv("https://raw.githubusercontent.com/Vinnythapz/Oasis/main/Advertising.csv")
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.tail()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
df.shape
# Out:
# (200, 5)

# %%
df.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]>

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# Unnamed: 0    0.0
# TV            0.0
# Radio         0.0
# Newspaper     0.0
# Sales         0.0
# dtype: float64

# %%
df.duplicated().sum()

# %%
df.columns =["Tv","Radio","Newspaper","Sales","Unnamed"]

# %%
import pandas as pd
for i in df.select_dtypes(include = 'object'). columns:
         print(df[i].value_counts())
         print("###"*10)

# %%
from matplotlib import pyplot as plt
df['Radio'].plot(kind='line', figsize=(8, 4), title='Radio')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Unnamed: 0']
  ys = series['Sales']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('Unnamed: 0', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Unnamed: 0')
_ = plt.ylabel('Sales')

# %%
from matplotlib import pyplot as plt
df.plot(kind='scatter', x='Radio', y='Newspaper', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
df['TV'].plot(kind='hist', bins=20, title='TV')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
import warnings
warnings.filterwarnings("ignore")

plt.close('all')
sns.set_style("whitegrid")
sns.pairplot(df,hue = "Sales", size=3,diag_kind ="kde")
plt.show()

# %%
pd.get_dummies(data=df, columns=["Tv", "Radio"], drop_first=True)
# Out:
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_19['Tv_5'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_19, x='Newspaper', y='Tv_5', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
#      Newspaper  Sales  Unnamed   Tv_2   Tv_3   Tv_4   Tv_5   Tv_6   Tv_7  \
# 0         37.8   69.2     22.1  False  False  False  False  False  False
# 1         39.3   45.1     10.4   True  False  False  False  False  False
# 2         45.9   69.3      9.3  False   True  False  False  False  False
# 3         41.3   58.5     18.5  False  False   True  False  False  False
# 4         10.8   58.4     12.9  False  False  False   True  False  False
# ..         ...    ...      ...    ...    ...    ...    ...    ...    ...
# 195        3.7   13.8      7.6  False  False  False  False  False  False
# 196        4.9    8.1      9.7  False  False  False  False  False  False
# ...

# %%
dummies = pd.get_dummies(data=df, columns=["Tv", "Radio"], drop_first=True)

# %%
print(dummies)
# Out:
#      Newspaper  Sales  Unnamed   Tv_2   Tv_3   Tv_4   Tv_5   Tv_6   Tv_7  \
# 0         37.8   69.2     22.1  False  False  False  False  False  False
# 1         39.3   45.1     10.4   True  False  False  False  False  False
# 2         45.9   69.3      9.3  False   True  False  False  False  False
# 3         41.3   58.5     18.5  False  False   True  False  False  False
# 4         10.8   58.4     12.9  False  False  False   True  False  False
# ..         ...    ...      ...    ...    ...    ...    ...    ...    ...
# 195        3.7   13.8      7.6  False  False  False  False  False  False
# 196        4.9    8.1      9.7  False  False  False  False  False  False
# 197        9.3    6.4     12.8  False  False  False  False  False  False
# 198       42.0   66.2     25.5  False  False  False  False  False  False
# 199        8.6    8.7     13.4  False  False  False  False  False  False
#
#       Tv_8  ...  Radio_281.4  Radio_283.6  Radio_284.3  Radio_286.0  \
# ...
